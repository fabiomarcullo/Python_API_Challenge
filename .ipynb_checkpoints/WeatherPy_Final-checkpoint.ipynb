# %% [markdown]
# # WeatherPy
#
# ---
#
# ## To get started, the code required to generate random geographic coordinates and the nearest city to each latitude and longitude combination is provided.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
import requests
import time
import datetime
from scipy.stats import linregress


# Impor the OpenWeatherMap API key
from api_keys import weather_api_key
from api_keys import geoapify_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 602

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Base URL to work off                         
base_url = "http://api.openweathermap.org/data/2.5/weather?"

# Counter to go through data
record = 0
sets = 1

# Create DataFrame
city_data_df1 = pd.DataFrame({"City": cities})

city_data_df1["Country"] = ""
city_data_df1["Date"] = ""      
city_data_df1["Latitude"] = ""
city_data_df1["Longitude"] = ""
city_data_df1["Cloudiness (%)"] = ""
city_data_df1["Humidity (%)"] = ""
city_data_df1["Max Temp (F)"] = ""
city_data_df1["Wind Speed (mph)"] = ""


# Interate through Cities and retrieve data
print("Beginning Data Retrieval")
print("-----------------------------")


for index, row in city_data_df1.iterrows():
    
    city = row["City"]
    
    query_url = base_url + "appid=" + weather_api_key + "&q=" + city
    weather_response = requests.get(query_url).json()
 
    try:
        print(f"Processing Record {record}  of Set {sets} | {city}.")
        #print (query_url) 
        
        city_data_df1.loc[index, "Country"] = weather_response["sys"]["country"]     
        city_data_df1.loc[index, "Date"] = datetime.datetime.fromtimestamp(weather_response["dt"])
        city_data_df1.loc[index, "Latitude"] = weather_response["coord"]["lat"]
        city_data_df1.loc[index, "Longitude"] = weather_response["coord"]["lon"]
        city_data_df1.loc[index, "Cloudiness (%)"] = weather_response["clouds"]["all"]
        city_data_df1.loc[index, "Humidity (%)"] = weather_response["main"]["humidity"]
        city_data_df1.loc[index, "Max Temp (F)"] = 1.8 * (weather_response["main"]["temp_max"] - 273) + 32
        city_data_df1.loc[index, "Wind Speed (mph)"] = weather_response["wind"]["speed"]
               
    except:
        print(f"City not found...skipping {city}.")
        #print (query_url) 
        
    
    record = record + 1
    if record == 50:
        record = 0
        sets = sets + 1 

print("-----------------------------")        
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0  of Set 1 | bandarbeyla.
# Processing Record 1  of Set 1 | valparaiso.
# Processing Record 2  of Set 1 | abalak.
# Processing Record 3  of Set 1 | mahebourg.
# Processing Record 4  of Set 1 | thompson.
# Processing Record 5  of Set 1 | manokwari.
# Processing Record 6  of Set 1 | victoria.
# Processing Record 7  of Set 1 | chokurdakh.
# Processing Record 8  of Set 1 | la ronge.
# Processing Record 9  of Set 1 | rikitea.
# Processing Record 10  of Set 1 | pisco.
# Processing Record 11  of Set 1 | butaritari.
# Processing Record 12  of Set 1 | illoqqortoormiut.
# City not found...skipping illoqqortoormiut.
# Processing Record 13  of Set 1 | alofi.
# Processing Record 14  of Set 1 | busselton.
# Processing Record 15  of Set 1 | vaini.
# Processing Record 16  of Set 1 | bredasdorp.
# Processing Record 17  of Set 1 | opuwo.
# Processing Record 18  of Set 1 | izumo.
# Processing Record 19  of Set 1 | port lincoln.
# Processing Record 20  of Set 1 | punta arenas.
# Processing Record 21  of Set 1 | saskylakh.
# Processing Record 22  of Set 1 | mataura.
# Processing Record 23  of Set 1 | cape town.
# Processing Record 24  of Set 1 | ushuaia.
# Processing Record 25  of Set 1 | vao.
# Processing Record 26  of Set 1 | mongoumba.
# Processing Record 27  of Set 1 | hilo.
# Processing Record 28  of Set 1 | tucurui.
# Processing Record 29  of Set 1 | sao felix do xingu.
# Processing Record 30  of Set 1 | mambolo.
# Processing Record 31  of Set 1 | bereda.
# Processing Record 32  of Set 1 | kristiinankaupunki.
# Processing Record 33  of Set 1 | dzilam gonzalez.
# Processing Record 34  of Set 1 | aquiraz.
# Processing Record 35  of Set 1 | airai.
# Processing Record 36  of Set 1 | poya.
# Processing Record 37  of Set 1 | taolanaro.
# City not found...skipping taolanaro.
# Processing Record 38  of Set 1 | guangyuan.
# Processing Record 39  of Set 1 | hermanus.
# Processing Record 40  of Set 1 | saint pete beach.
# Processing Record 41  of Set 1 | kieta.
# Processing Record 42  of Set 1 | karratha.
# Processing Record 43  of Set 1 | qaanaaq.
# Processing Record 44  of Set 1 | wattegama.
# Processing Record 45  of Set 1 | kloulklubed.
# Processing Record 46  of Set 1 | pozo colorado.
# Processing Record 47  of Set 1 | lompoc.
# Processing Record 48  of Set 1 | georgetown.
# Processing Record 49  of Set 1 | lagoa.
# Processing Record 0  of Set 2 | mayo.
# Processing Record 1  of Set 2 | arlit.
# Processing Record 2  of Set 2 | tabou.
# Processing Record 3  of Set 2 | alibag.
# Processing Record 4  of Set 2 | port alfred.
# Processing Record 5  of Set 2 | malakal.
# Processing Record 6  of Set 2 | inhambane.
# Processing Record 7  of Set 2 | tasiilaq.
# Processing Record 8  of Set 2 | bluff.
# Processing Record 9  of Set 2 | luderitz.
# Processing Record 10  of Set 2 | santona.
# Processing Record 11  of Set 2 | kapaa.
# Processing Record 12  of Set 2 | atok.
# Processing Record 13  of Set 2 | mareeba.
# Processing Record 14  of Set 2 | cabarroguis.
# Processing Record 15  of Set 2 | tura.
# Processing Record 16  of Set 2 | maragogi.
# Processing Record 17  of Set 2 | vaitupu.
# City not found...skipping vaitupu.
# Processing Record 18  of Set 2 | codrington.
# Processing Record 19  of Set 2 | ahipara.
# Processing Record 20  of Set 2 | ponta do sol.
# Processing Record 21  of Set 2 | fairbanks.
# Processing Record 22  of Set 2 | coruripe.
# Processing Record 23  of Set 2 | new norfolk.
# Processing Record 24  of Set 2 | hithadhoo.
# Processing Record 25  of Set 2 | atuona.
# Processing Record 26  of Set 2 | hoegaarden.
# Processing Record 27  of Set 2 | hami.
# Processing Record 28  of Set 2 | kazuno.
# Processing Record 29  of Set 2 | tuktoyaktuk.
# Processing Record 30  of Set 2 | constitucion.
# Processing Record 31  of Set 2 | lebu.
# Processing Record 32  of Set 2 | eraclea.
# Processing Record 33  of Set 2 | kamenskoye.
# City not found...skipping kamenskoye.
# Processing Record 34  of Set 2 | labutta.
# City not found...skipping labutta.
# Processing Record 35  of Set 2 | barrow.
# Processing Record 36  of Set 2 | alugan.
# Processing Record 37  of Set 2 | albany.
# Processing Record 38  of Set 2 | tabas.
# Processing Record 39  of Set 2 | kalevala.
# Processing Record 40  of Set 2 | khatanga.
# Processing Record 41  of Set 2 | saint-philippe.
# Processing Record 42  of Set 2 | nova olinda do norte.
# Processing Record 43  of Set 2 | arraial do cabo.
# Processing Record 44  of Set 2 | vanimo.
# Processing Record 45  of Set 2 | torbay.
# Processing Record 46  of Set 2 | jamestown.
# Processing Record 47  of Set 2 | tiksi.
# Processing Record 48  of Set 2 | hagi.
# Processing Record 49  of Set 2 | faanui.
# Processing Record 0  of Set 3 | seoul.
# Processing Record 1  of Set 3 | sioux lookout.
# Processing Record 2  of Set 3 | beidao.
# Processing Record 3  of Set 3 | la quinta.
# Processing Record 4  of Set 3 | bonthe.
# Processing Record 5  of Set 3 | portland.
# Processing Record 6  of Set 3 | jumla.
# Processing Record 7  of Set 3 | upernavik.
# Processing Record 8  of Set 3 | itoman.
# Processing Record 9  of Set 3 | margate.
# Processing Record 10  of Set 3 | foam lake.
# Processing Record 11  of Set 3 | najran.
# Processing Record 12  of Set 3 | havelock.
# Processing Record 13  of Set 3 | barentsburg.
# City not found...skipping barentsburg.
# Processing Record 14  of Set 3 | bagh.
# Processing Record 15  of Set 3 | puerto ayora.
# Processing Record 16  of Set 3 | yellowknife.
# Processing Record 17  of Set 3 | kaitangata.
# Processing Record 18  of Set 3 | vestmannaeyjar.
# Processing Record 19  of Set 3 | ixtapa.
# Processing Record 20  of Set 3 | kegayli.
# City not found...skipping kegayli.
# Processing Record 21  of Set 3 | vila.
# Processing Record 22  of Set 3 | tanete.
# Processing Record 23  of Set 3 | diamantino.
# Processing Record 24  of Set 3 | santa isabel.
# Processing Record 25  of Set 3 | ribeira grande.
# Processing Record 26  of Set 3 | amderma.
# City not found...skipping amderma.
# Processing Record 27  of Set 3 | maykor.
# Processing Record 28  of Set 3 | am timan.
# Processing Record 29  of Set 3 | makakilo city.
# Processing Record 30  of Set 3 | calama.
# Processing Record 31  of Set 3 | sur.
# Processing Record 32  of Set 3 | los llanos de aridane.
# Processing Record 33  of Set 3 | dikson.
# Processing Record 34  of Set 3 | vangaindrano.
# Processing Record 35  of Set 3 | uddiawan.
# Processing Record 36  of Set 3 | nong bua.
# Processing Record 37  of Set 3 | gulshat.
# City not found...skipping gulshat.
# Processing Record 38  of Set 3 | savalou.
# Processing Record 39  of Set 3 | grand gaube.
# Processing Record 40  of Set 3 | saldanha.
# Processing Record 41  of Set 3 | formoso do araguaia.
# City not found...skipping formoso do araguaia.
# Processing Record 42  of Set 3 | saryshagan.
# City not found...skipping saryshagan.
# Processing Record 43  of Set 3 | nepalganj.
# City not found...skipping nepalganj.
# Processing Record 44  of Set 3 | mogadishu.
# Processing Record 45  of Set 3 | norman wells.
# Processing Record 46  of Set 3 | saint george.
# Processing Record 47  of Set 3 | ukmerge.
# Processing Record 48  of Set 3 | carnarvon.
# Processing Record 49  of Set 3 | coquimbo.
# Processing Record 0  of Set 4 | souillac.
# Processing Record 1  of Set 4 | sinkat.
# City not found...skipping sinkat.
# Processing Record 2  of Set 4 | pangnirtung.
# Processing Record 3  of Set 4 | vostok.
# Processing Record 4  of Set 4 | mys shmidta.
# City not found...skipping mys shmidta.
# Processing Record 5  of Set 4 | mahibadhoo.
# Processing Record 6  of Set 4 | rio gallegos.
# Processing Record 7  of Set 4 | bengkulu.
# Processing Record 8  of Set 4 | bethel.
# Processing Record 9  of Set 4 | puerto escondido.
# Processing Record 10  of Set 4 | mar del plata.
# Processing Record 11  of Set 4 | taihe.
# Processing Record 12  of Set 4 | bolobo.
# Processing Record 13  of Set 4 | zacualpan.
# Processing Record 14  of Set 4 | touros.
# Processing Record 15  of Set 4 | shambu.
# Processing Record 16  of Set 4 | veraval.
# Processing Record 17  of Set 4 | pervomayskiy.
# Processing Record 18  of Set 4 | ayan.
# Processing Record 19  of Set 4 | bondo.
# Processing Record 20  of Set 4 | la paz.
# Processing Record 21  of Set 4 | husavik.
# Processing Record 22  of Set 4 | mogok.
# Processing Record 23  of Set 4 | chunskiy.
# Processing Record 24  of Set 4 | castro.
# Processing Record 25  of Set 4 | bontang.
# Processing Record 26  of Set 4 | lucapa.
# Processing Record 27  of Set 4 | bonavista.
# Processing Record 28  of Set 4 | port macquarie.
# Processing Record 29  of Set 4 | khasan.
# Processing Record 30  of Set 4 | kununurra.
# Processing Record 31  of Set 4 | port elizabeth.
# Processing Record 32  of Set 4 | salalah.
# Processing Record 33  of Set 4 | surgut.
# Processing Record 34  of Set 4 | sao mateus.
# Processing Record 35  of Set 4 | tabiauea.
# City not found...skipping tabiauea.
# Processing Record 36  of Set 4 | jose bonifacio.
# Processing Record 37  of Set 4 | ovalle.
# Processing Record 38  of Set 4 | nortelandia.
# Processing Record 39  of Set 4 | praia.
# Processing Record 40  of Set 4 | linxia.
# Processing Record 41  of Set 4 | laguna.
# Processing Record 42  of Set 4 | el banco.
# Processing Record 43  of Set 4 | mokhsogollokh.
# Processing Record 44  of Set 4 | narsaq.
# Processing Record 45  of Set 4 | nanortalik.
# Processing Record 46  of Set 4 | sumbawa.
# City not found...skipping sumbawa.
# Processing Record 47  of Set 4 | antsohihy.
# Processing Record 48  of Set 4 | nome.
# Processing Record 49  of Set 4 | nizhniy baskunchak.
# Processing Record 0  of Set 5 | severo-kurilsk.
# Processing Record 1  of Set 5 | hobart.
# Processing Record 2  of Set 5 | esperance.
# Processing Record 3  of Set 5 | merauke.
# Processing Record 4  of Set 5 | haines junction.
# Processing Record 5  of Set 5 | kruisfontein.
# Processing Record 6  of Set 5 | nevelsk.
# Processing Record 7  of Set 5 | kodiak.
# Processing Record 8  of Set 5 | nikolskoye.
# Processing Record 9  of Set 5 | biltine.
# Processing Record 10  of Set 5 | aksarka.
# Processing Record 11  of Set 5 | nguiu.
# City not found...skipping nguiu.
# Processing Record 12  of Set 5 | tuatapere.
# Processing Record 13  of Set 5 | sistranda.
# Processing Record 14  of Set 5 | banamba.
# Processing Record 15  of Set 5 | berlevag.
# Processing Record 16  of Set 5 | drumheller.
# Processing Record 17  of Set 5 | ancud.
# Processing Record 18  of Set 5 | antofagasta.
# Processing Record 19  of Set 5 | kainantu.
# Processing Record 20  of Set 5 | kidal.
# Processing Record 21  of Set 5 | sortavala.
# Processing Record 22  of Set 5 | luanda.
# Processing Record 23  of Set 5 | hlotse.
# Processing Record 24  of Set 5 | itarema.
# Processing Record 25  of Set 5 | shumyachi.
# Processing Record 26  of Set 5 | samusu.
# City not found...skipping samusu.
# Processing Record 27  of Set 5 | skibbereen.
# Processing Record 28  of Set 5 | ahumada.
# City not found...skipping ahumada.
# Processing Record 29  of Set 5 | belaya gora.
# Processing Record 30  of Set 5 | aldan.
# Processing Record 31  of Set 5 | vila franca do campo.
# Processing Record 32  of Set 5 | porto walter.
# Processing Record 33  of Set 5 | aswan.
# Processing Record 34  of Set 5 | leningradskiy.
# Processing Record 35  of Set 5 | avarua.
# Processing Record 36  of Set 5 | dolinsk.
# Processing Record 37  of Set 5 | sarangani.
# Processing Record 38  of Set 5 | clyde river.
# Processing Record 39  of Set 5 | cidreira.
# Processing Record 40  of Set 5 | dubbo.
# Processing Record 41  of Set 5 | khandbari.
# Processing Record 42  of Set 5 | yafran.
# Processing Record 43  of Set 5 | pevek.
# Processing Record 44  of Set 5 | olinda.
# Processing Record 45  of Set 5 | gamba.
# Processing Record 46  of Set 5 | nchelenge.
# Processing Record 47  of Set 5 | amapa.
# Processing Record 48  of Set 5 | mutsamudu.
# City not found...skipping mutsamudu.
# Processing Record 49  of Set 5 | klaksvik.
# Processing Record 0  of Set 6 | albanel.
# Processing Record 1  of Set 6 | singaraja.
# Processing Record 2  of Set 6 | jawhar.
# Processing Record 3  of Set 6 | hokitika.
# Processing Record 4  of Set 6 | kochkurovo.
# Processing Record 5  of Set 6 | satitoa.
# City not found...skipping satitoa.
# Processing Record 6  of Set 6 | hihifo.
# City not found...skipping hihifo.
# Processing Record 7  of Set 6 | great falls.
# Processing Record 8  of Set 6 | umzimvubu.
# City not found...skipping umzimvubu.
# Processing Record 9  of Set 6 | panaba.
# Processing Record 10  of Set 6 | thunder bay.
# Processing Record 11  of Set 6 | biloela.
# Processing Record 12  of Set 6 | karkaralinsk.
# City not found...skipping karkaralinsk.
# Processing Record 13  of Set 6 | westport.
# Processing Record 14  of Set 6 | shimoda.
# Processing Record 15  of Set 6 | dunedin.
# Processing Record 16  of Set 6 | cherskiy.
# Processing Record 17  of Set 6 | longyearbyen.
# Processing Record 18  of Set 6 | mandera.
# Processing Record 19  of Set 6 | bosaso.
# Processing Record 20  of Set 6 | ghanzi.
# Processing Record 21  of Set 6 | college.
# Processing Record 22  of Set 6 | nogales.
# Processing Record 23  of Set 6 | kahta.
# Processing Record 24  of Set 6 | puerto del rosario.
# Processing Record 25  of Set 6 | van buren.
# Processing Record 26  of Set 6 | tautira.
# Processing Record 27  of Set 6 | gravdal.
# Processing Record 28  of Set 6 | sexsmith.
# Processing Record 29  of Set 6 | iqaluit.
# Processing Record 30  of Set 6 | tsihombe.
# City not found...skipping tsihombe.
# Processing Record 31  of Set 6 | yumen.
# Processing Record 32  of Set 6 | coahuayana.
# Processing Record 33  of Set 6 | cascais.
# Processing Record 34  of Set 6 | male.
# Processing Record 35  of Set 6 | el alto.
# Processing Record 36  of Set 6 | hasaki.
# Processing Record 37  of Set 6 | paamiut.
# Processing Record 38  of Set 6 | sinegorye.
# Processing Record 39  of Set 6 | yatou.
# Processing Record 40  of Set 6 | zhuhai.
# Processing Record 41  of Set 6 | ponta delgada.
# Processing Record 42  of Set 6 | saint anthony.
# Processing Record 43  of Set 6 | mecca.
# Processing Record 44  of Set 6 | hervey bay.
# Processing Record 45  of Set 6 | san-pedro.
# Processing Record 46  of Set 6 | stege.
# Processing Record 47  of Set 6 | grand river south east.
# City not found...skipping grand river south east.
# Processing Record 48  of Set 6 | bambous virieux.
# Processing Record 49  of Set 6 | vardo.
# Processing Record 0  of Set 7 | guerrero negro.
# Processing Record 1  of Set 7 | rosetta.
# Processing Record 2  of Set 7 | gat.
# Processing Record 3  of Set 7 | ducheng.
# Processing Record 4  of Set 7 | acapulco.
# Processing Record 5  of Set 7 | savelugu.
# Processing Record 6  of Set 7 | thinadhoo.
# Processing Record 7  of Set 7 | karaul.
# City not found...skipping karaul.
# Processing Record 8  of Set 7 | nuevitas.
# Processing Record 9  of Set 7 | albi.
# Processing Record 10  of Set 7 | arawa.
# Processing Record 11  of Set 7 | richard toll.
# City not found...skipping richard toll.
# Processing Record 12  of Set 7 | esso.
# Processing Record 13  of Set 7 | kuche.
# City not found...skipping kuche.
# Processing Record 14  of Set 7 | adrar.
# Processing Record 15  of Set 7 | kathmandu.
# Processing Record 16  of Set 7 | bubaque.
# Processing Record 17  of Set 7 | polson.
# Processing Record 18  of Set 7 | sitka.
# Processing Record 19  of Set 7 | taltal.
# Processing Record 20  of Set 7 | ola.
# Processing Record 21  of Set 7 | naze.
# Processing Record 22  of Set 7 | viedma.
# Processing Record 23  of Set 7 | lavrentiya.
# Processing Record 24  of Set 7 | foumbot.
# Processing Record 25  of Set 7 | hirara.
# Processing Record 26  of Set 7 | changqing.
# Processing Record 27  of Set 7 | wanning.
# Processing Record 28  of Set 7 | igurusi.
# Processing Record 29  of Set 7 | farafenni.
# Processing Record 30  of Set 7 | gafanha da encarnacao.
# Processing Record 31  of Set 7 | morgan city.
# Processing Record 32  of Set 7 | asyut.
# Processing Record 33  of Set 7 | omagh.
# Processing Record 34  of Set 7 | belushya guba.
# City not found...skipping belushya guba.
# Processing Record 35  of Set 7 | kavieng.
# Processing Record 36  of Set 7 | kamenka.
# Processing Record 37  of Set 7 | aflu.
# City not found...skipping aflu.
# Processing Record 38  of Set 7 | manono.
# Processing Record 39  of Set 7 | jacqueville.
# Processing Record 40  of Set 7 | jiddah.
# City not found...skipping jiddah.
# Processing Record 41  of Set 7 | gigmoto.
# Processing Record 42  of Set 7 | taga dzong.
# City not found...skipping taga dzong.
# Processing Record 43  of Set 7 | vankleek hill.
# Processing Record 44  of Set 7 | ambulu.
# Processing Record 45  of Set 7 | kattivakkam.
# Processing Record 46  of Set 7 | brae.
# Processing Record 47  of Set 7 | palasa.
# Processing Record 48  of Set 7 | provideniya.
# Processing Record 49  of Set 7 | richards bay.
# Processing Record 0  of Set 8 | north platte.
# Processing Record 1  of Set 8 | sao lourenco do oeste.
# Processing Record 2  of Set 8 | marv dasht.
# City not found...skipping marv dasht.
# Processing Record 3  of Set 8 | maldonado.
# Processing Record 4  of Set 8 | dutlwe.
# Processing Record 5  of Set 8 | tiznit.
# Processing Record 6  of Set 8 | carballo.
# Processing Record 7  of Set 8 | taoudenni.
# Processing Record 8  of Set 8 | mayumba.
# Processing Record 9  of Set 8 | santa eulalia del rio.
# City not found...skipping santa eulalia del rio.
# Processing Record 10  of Set 8 | honiara.
# Processing Record 11  of Set 8 | progreso.
# Processing Record 12  of Set 8 | marcona.
# City not found...skipping marcona.
# Processing Record 13  of Set 8 | dabat.
# Processing Record 14  of Set 8 | aguadilla.
# Processing Record 15  of Set 8 | rincon.
# Processing Record 16  of Set 8 | port hedland.
# Processing Record 17  of Set 8 | palmer.
# Processing Record 18  of Set 8 | chuy.
# Processing Record 19  of Set 8 | solenzo.
# Processing Record 20  of Set 8 | shangqiu.
# Processing Record 21  of Set 8 | hofn.
# Processing Record 22  of Set 8 | papar.
# Processing Record 23  of Set 8 | la concordia.
# Processing Record 24  of Set 8 | sarapul.
# Processing Record 25  of Set 8 | ilulissat.
# Processing Record 26  of Set 8 | batagay-alyta.
# Processing Record 27  of Set 8 | bolungarvik.
# City not found...skipping bolungarvik.
# Processing Record 28  of Set 8 | keetmanshoop.
# Processing Record 29  of Set 8 | sao filipe.
# Processing Record 30  of Set 8 | kalaleh.
# Processing Record 31  of Set 8 | parana.
# Processing Record 32  of Set 8 | lokosovo.
# Processing Record 33  of Set 8 | dzhebariki-khaya.
# Processing Record 34  of Set 8 | feicheng.
# Processing Record 35  of Set 8 | priupskiy.
# Processing Record 36  of Set 8 | moose factory.
# Processing Record 37  of Set 8 | bilibino.
# Processing Record 38  of Set 8 | redmond.
# Processing Record 39  of Set 8 | mandla.
# Processing Record 40  of Set 8 | afmadu.
# City not found...skipping afmadu.
# Processing Record 41  of Set 8 | muros.
# Processing Record 42  of Set 8 | lhokseumawe.
# Processing Record 43  of Set 8 | kiruna.
# Processing Record 44  of Set 8 | san quintin.
# Processing Record 45  of Set 8 | burkhala.
# City not found...skipping burkhala.
# Processing Record 46  of Set 8 | kalianget.
# Processing Record 47  of Set 8 | hazorasp.
# Processing Record 48  of Set 8 | high level.
# Processing Record 49  of Set 8 | sentyabrskiy.
# City not found...skipping sentyabrskiy.
# Processing Record 0  of Set 9 | makung.
# City not found...skipping makung.
# Processing Record 1  of Set 9 | srednekolymsk.
# Processing Record 2  of Set 9 | axim.
# Processing Record 3  of Set 9 | galveston.
# Processing Record 4  of Set 9 | avera.
# Processing Record 5  of Set 9 | abha.
# Processing Record 6  of Set 9 | port augusta.
# Processing Record 7  of Set 9 | angoche.
# Processing Record 8  of Set 9 | vestmanna.
# Processing Record 9  of Set 9 | manaure.
# Processing Record 10  of Set 9 | tunduru.
# City not found...skipping tunduru.
# Processing Record 11  of Set 9 | matay.
# Processing Record 12  of Set 9 | maralal.
# Processing Record 13  of Set 9 | goiatuba.
# Processing Record 14  of Set 9 | gold coast.
# Processing Record 15  of Set 9 | zhaotong.
# Processing Record 16  of Set 9 | tumannyy.
# City not found...skipping tumannyy.
# Processing Record 17  of Set 9 | pryozerne.
# Processing Record 18  of Set 9 | trofors.
# Processing Record 19  of Set 9 | las palmas.
# Processing Record 20  of Set 9 | marquette.
# Processing Record 21  of Set 9 | barcelos.
# Processing Record 22  of Set 9 | tuggurt.
# City not found...skipping tuggurt.
# Processing Record 23  of Set 9 | port blair.
# Processing Record 24  of Set 9 | bayir.
# Processing Record 25  of Set 9 | yerbogachen.
# Processing Record 26  of Set 9 | astoria.
# Processing Record 27  of Set 9 | da nang.
# Processing Record 28  of Set 9 | batemans bay.
# Processing Record 29  of Set 9 | whyalla.
# Processing Record 30  of Set 9 | pochutla.
# Processing Record 31  of Set 9 | sukhoy log.
# Processing Record 32  of Set 9 | tucupita.
# Processing Record 33  of Set 9 | soyo.
# Processing Record 34  of Set 9 | nelson.
# Processing Record 35  of Set 9 | bastia.
# Processing Record 36  of Set 9 | san cristobal.
# Processing Record 37  of Set 9 | tamiahua.
# Processing Record 38  of Set 9 | brownwood.
# Processing Record 39  of Set 9 | pangkalanbuun.
# Processing Record 40  of Set 9 | severo-yeniseyskiy.
# Processing Record 41  of Set 9 | ginir.
# Processing Record 42  of Set 9 | chillicothe.
# Processing Record 43  of Set 9 | baykit.
# Processing Record 44  of Set 9 | dondukovskaya.
# Processing Record 45  of Set 9 | tomatlan.
# Processing Record 46  of Set 9 | zhigansk.
# Processing Record 47  of Set 9 | cabo san lucas.
# Processing Record 48  of Set 9 | komsomolskiy.
# Processing Record 49  of Set 9 | ust-ilimsk.
# Processing Record 0  of Set 10 | fortuna.
# Processing Record 1  of Set 10 | yamada.
# Processing Record 2  of Set 10 | villa maria.
# Processing Record 3  of Set 10 | humaita.
# Processing Record 4  of Set 10 | naron.
# Processing Record 5  of Set 10 | lubango.
# Processing Record 6  of Set 10 | navalcarnero.
# Processing Record 7  of Set 10 | sobotka.
# Processing Record 8  of Set 10 | chicama.
# Processing Record 9  of Set 10 | kula.
# Processing Record 10  of Set 10 | florianopolis.
# Processing Record 11  of Set 10 | rozivka.
# Processing Record 12  of Set 10 | mount gambier.
# Processing Record 13  of Set 10 | takhli.
# Processing Record 14  of Set 10 | pietermaritzburg.
# Processing Record 15  of Set 10 | bharwari.
# Processing Record 16  of Set 10 | hohhot.
# Processing Record 17  of Set 10 | saint-augustin.
# Processing Record 18  of Set 10 | isla vista.
# Processing Record 19  of Set 10 | anadyr.
# Processing Record 20  of Set 10 | saleaula.
# City not found...skipping saleaula.
# Processing Record 21  of Set 10 | roma.
# Processing Record 22  of Set 10 | teya.
# Processing Record 23  of Set 10 | urucara.
# Processing Record 24  of Set 10 | amga.
# Processing Record 25  of Set 10 | tatsinskaya.
# City not found...skipping tatsinskaya.
# Processing Record 26  of Set 10 | san francisco.
# Processing Record 27  of Set 10 | simao.
# Processing Record 28  of Set 10 | tual.
# Processing Record 29  of Set 10 | yar-sale.
# Processing Record 30  of Set 10 | praya.
# Processing Record 31  of Set 10 | dakar.
# Processing Record 32  of Set 10 | nhulunbuy.
# Processing Record 33  of Set 10 | khormuj.
# City not found...skipping khormuj.
# Processing Record 34  of Set 10 | presidente olegario.
# Processing Record 35  of Set 10 | nizhneyansk.
# City not found...skipping nizhneyansk.
# Processing Record 36  of Set 10 | diu.
# Processing Record 37  of Set 10 | mount pleasant.
# Processing Record 38  of Set 10 | nava.
# Processing Record 39  of Set 10 | kandrian.
# Processing Record 40  of Set 10 | tamboril.
# Processing Record 41  of Set 10 | santo angelo.
# Processing Record 42  of Set 10 | aljezur.
# Processing Record 43  of Set 10 | kudahuvadhoo.
# Processing Record 44  of Set 10 | durango.
# Processing Record 45  of Set 10 | gergebil.
# Processing Record 46  of Set 10 | sambava.
# Processing Record 47  of Set 10 | olsztyn.
# Processing Record 48  of Set 10 | yokadouma.
# Processing Record 49  of Set 10 | nata.
# Processing Record 0  of Set 11 | ambovombe.
# Processing Record 1  of Set 11 | toppenish.
# Processing Record 2  of Set 11 | rocha.
# Processing Record 3  of Set 11 | namibe.
# Processing Record 4  of Set 11 | waingapu.
# Processing Record 5  of Set 11 | vila velha.
# Processing Record 6  of Set 11 | impfondo.
# Processing Record 7  of Set 11 | melfort.
# Processing Record 8  of Set 11 | saraland.
# Processing Record 9  of Set 11 | east london.
# Processing Record 10  of Set 11 | cuauhtemoc.
# Processing Record 11  of Set 11 | turukhansk.
# Processing Record 12  of Set 11 | esmeraldas.
# Processing Record 13  of Set 11 | kuala terengganu.
# Processing Record 14  of Set 11 | talcahuano.
# Processing Record 15  of Set 11 | aklavik.
# Processing Record 16  of Set 11 | hamilton.
# Processing Record 17  of Set 11 | toftir.
# City not found...skipping toftir.
# Processing Record 18  of Set 11 | san patricio.
# Processing Record 19  of Set 11 | pangody.
# Processing Record 20  of Set 11 | olean.
# Processing Record 21  of Set 11 | umm ruwabah.
# City not found...skipping umm ruwabah.
# Processing Record 22  of Set 11 | manta.
# Processing Record 23  of Set 11 | beirut.
# Processing Record 24  of Set 11 | sabancuy.
# Processing Record 25  of Set 11 | saint-pierre.
# Processing Record 26  of Set 11 | asfi.
# Processing Record 27  of Set 11 | vila do maio.
# Processing Record 28  of Set 11 | upata.
# Processing Record 29  of Set 11 | vredendal.
# Processing Record 30  of Set 11 | joensuu.
# Processing Record 31  of Set 11 | chapais.
# Processing Record 32  of Set 11 | neuquen.
# Processing Record 33  of Set 11 | elko.
# Processing Record 34  of Set 11 | sivaki.
# Processing Record 35  of Set 11 | the valley.
# Processing Record 36  of Set 11 | fort nelson.
# Processing Record 37  of Set 11 | aktash.
# Processing Record 38  of Set 11 | medicine hat.
# Processing Record 39  of Set 11 | okato.
# Processing Record 40  of Set 11 | oussouye.
# Processing Record 41  of Set 11 | hobyo.
# Processing Record 42  of Set 11 | georgiyevka.
# Processing Record 43  of Set 11 | arkadelphia.
# Processing Record 44  of Set 11 | ojinaga.
# Processing Record 45  of Set 11 | gushi.
# Processing Record 46  of Set 11 | mtwara.
# Processing Record 47  of Set 11 | pundaguitan.
# Processing Record 48  of Set 11 | crestview.
# Processing Record 49  of Set 11 | nuuk.
# Processing Record 0  of Set 12 | beni mazar.
# Processing Record 1  of Set 12 | mayenne.
# Processing Record 2  of Set 12 | abu zabad.
# Processing Record 3  of Set 12 | sibolga.
# Processing Record 4  of Set 12 | aykhal.
# Processing Record 5  of Set 12 | champasak.
# Processing Record 6  of Set 12 | erzincan.
# Processing Record 7  of Set 12 | broome.
# Processing Record 8  of Set 12 | egvekinot.
# Processing Record 9  of Set 12 | pacifica.
# Processing Record 10  of Set 12 | cam pha.
# City not found...skipping cam pha.
# Processing Record 11  of Set 12 | temir.
# Processing Record 12  of Set 12 | kasongo-lunda.
# Processing Record 13  of Set 12 | palabuhanratu.
# City not found...skipping palabuhanratu.
# Processing Record 14  of Set 12 | mount isa.
# Processing Record 15  of Set 12 | southbridge.
# Processing Record 16  of Set 12 | coihaique.
# Processing Record 17  of Set 12 | ostrovnoy.
# Processing Record 18  of Set 12 | ishigaki.
# Processing Record 19  of Set 12 | aleksandrovsk-sakhalinskiy.
# Processing Record 20  of Set 12 | caxito.
# Processing Record 21  of Set 12 | dingle.
# Processing Record 22  of Set 12 | svetlaya.
# Processing Record 23  of Set 12 | olafsvik.
# Processing Record 24  of Set 12 | teyateyaneng.
# Processing Record 25  of Set 12 | barra patuca.
# Processing Record 26  of Set 12 | sibu.
# Processing Record 27  of Set 12 | bara.
# Processing Record 28  of Set 12 | whitley bay.
# Processing Record 29  of Set 12 | meulaboh.
# Processing Record 30  of Set 12 | nouadhibou.
# Processing Record 31  of Set 12 | betlitsa.
# Processing Record 32  of Set 12 | matara.
# Processing Record 33  of Set 12 | christchurch.
# Processing Record 34  of Set 12 | bathsheba.
# Processing Record 35  of Set 12 | palm coast.
# Processing Record 36  of Set 12 | baijiantan.
# Processing Record 37  of Set 12 | attawapiskat.
# City not found...skipping attawapiskat.
# Processing Record 38  of Set 12 | mae sai.
# Processing Record 39  of Set 12 | flinders.
# Processing Record 40  of Set 12 | talnakh.
# Processing Record 41  of Set 12 | marsh harbour.
# Processing Record 42  of Set 12 | ypsonas.
# Processing Record 43  of Set 12 | voh.
# Processing Record 44  of Set 12 | sao joao da barra.
# Processing Record 45  of Set 12 | skegness.
# Processing Record 46  of Set 12 | masandra.
# City not found...skipping masandra.
# Processing Record 47  of Set 12 | nacozari.
# Processing Record 48  of Set 12 | tessalit.
# Processing Record 49  of Set 12 | mkushi.
# Processing Record 0  of Set 13 | shingu.
# Processing Record 1  of Set 13 | kamina.
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Data Count

city_data_df = city_data_df1.dropna()

city_data_df.count()
# Out:
# City                602
# Country             602
# Date                602
# Latitude            602
# Longitude           602
# Cloudiness (%)      602
# Humidity (%)        602
# Max Temp (F)        602
# Wind Speed (mph)    602
# dtype: int64

# %%
# Display DataFrame
city_data_df.head()
# Out:
#           City Country                 Date Latitude Longitude Cloudiness (%)  \
# 0  bandarbeyla      SO  2023-04-14 11:27:48   9.4942   50.8122             54
# 1   valparaiso      CL  2023-04-14 11:26:05 -33.0393  -71.6273             75
# 2       abalak      RU  2023-04-14 11:27:48  58.1286   68.5944              2
# 3    mahebourg      MU  2023-04-14 11:27:49 -20.4081      57.7             75
# 4     thompson      CA  2023-04-14 11:26:50  55.7435  -97.8558             75
#
#   Humidity (%) Max Temp (F) Wind Speed (mph)
# 0           75       84.074             5.45
# 1           69        64.31             1.03
# 2           44       21.704             3.45
# 3           83       81.158                0
# 4           56       39.632             2.57

# %%
# Convert data strings to float
pd.to_numeric(city_data_df["Cloudiness (%)"]).astype(float)
pd.to_numeric(city_data_df["Humidity (%)"]).astype(float)
pd.to_numeric(city_data_df["Latitude"]).astype(float)
pd.to_numeric(city_data_df["Longitude"]).astype(float)
pd.to_numeric(city_data_df["Max Temp (F)"]).astype(float)
pd.to_numeric(city_data_df["Wind Speed (mph)"]).astype(float)
city_data_df

#Export DataFrame to CSV File
city_data_df.to_csv("weather_df.csv")
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City Country                 Date  Latitude  Longitude  \
# City_ID
# 0        bandarbeyla      SO  2023-04-14 11:27:48    9.4942    50.8122
# 1         valparaiso      CL  2023-04-14 11:26:05  -33.0393   -71.6273
# 2             abalak      RU  2023-04-14 11:27:48   58.1286    68.5944
# 3          mahebourg      MU  2023-04-14 11:27:49  -20.4081    57.7000
# 4           thompson      CA  2023-04-14 11:26:50   55.7435   -97.8558
#
#          Cloudiness (%)  Humidity (%)  Max Temp (F)  Wind Speed (mph)
# City_ID
# 0                  54.0          75.0        84.074              5.45
# 1                  75.0          69.0        64.310              1.03
# 2                   2.0          44.0        21.704              3.45
# 3                  75.0          83.0        81.158              0.00
# 4                  75.0          56.0        39.632              2.57

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(city_data_df["Latitude"]).astype(float), pd.to_numeric(city_data_df["Max Temp (F)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title(f"City Latitude vs Max Temperature ({today})")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(city_data_df["Latitude"]).astype(float), pd.to_numeric(city_data_df["Humidity (%)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)


# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs Humidity (%) ({today})")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(city_data_df["Latitude"]).astype(float), pd.to_numeric(city_data_df["Cloudiness (%)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)


# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs Cloudiness ({today})")


# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(city_data_df["Latitude"]).astype(float), pd.to_numeric(city_data_df["Wind Speed (mph)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)


# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"City Latitude vs Wind Speed ({today})")


# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_df = city_data_df.loc[pd.to_numeric(city_data_df["Latitude"]).astype(float) > 0, :]

# Display sample data
northern_df.head()
# Out:
#                 City Country                 Date  Latitude  Longitude  \
# City_ID
# 0        bandarbeyla      SO  2023-04-14 11:27:48    9.4942    50.8122
# 2             abalak      RU  2023-04-14 11:27:48   58.1286    68.5944
# 4           thompson      CA  2023-04-14 11:26:50   55.7435   -97.8558
# 6           victoria      HK  2023-04-14 11:27:05   22.2855   114.1577
# 7         chokurdakh      RU  2023-04-14 11:27:50   70.6333   147.9167
#
#          Cloudiness (%)  Humidity (%)  Max Temp (F)  Wind Speed (mph)
# City_ID
# 0                  54.0          75.0        84.074              5.45
# 2                   2.0          44.0        21.704              3.45
# 4                  75.0          56.0        39.632              2.57
# 6                   1.0          87.0        78.476              2.40
# 7                 100.0          96.0         3.452              1.69

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_df = city_data_df.loc[pd.to_numeric(city_data_df["Latitude"]).astype(float) < 0, :]

# Display sample data
southern_df.head()
# Out:
#                City Country                 Date  Latitude  Longitude  \
# City_ID
# 1        valparaiso      CL  2023-04-14 11:26:05  -33.0393   -71.6273
# 3         mahebourg      MU  2023-04-14 11:27:49  -20.4081    57.7000
# 5         manokwari      ID  2023-04-14 11:27:49   -0.8667   134.0833
# 9           rikitea      PF  2023-04-14 11:27:50  -23.1203  -134.9692
# 10            pisco      PE  2023-04-14 11:27:50  -13.7000   -76.2167
#
#          Cloudiness (%)  Humidity (%)  Max Temp (F)  Wind Speed (mph)
# City_ID
# 1                  75.0          69.0        64.310              1.03
# 3                  75.0          83.0        81.158              0.00
# 5                  55.0          80.0        79.754              2.40
# 9                  79.0          76.0        78.080              7.38
# 10                  0.0          61.0        80.924              5.66

# %% [markdown]
# **Discussion about the linear relationship:** Notes on the top of each Plot

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Max Temp (F)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a negative correlation.")
print("In the nothern hemisphere, as you move away from the equator the temperature decreases.")
plt.show()
# Out:
# Regression line equation is: y = -1.2x + 102.21
# The r-squared is: -0.8628149514383118
# The regression displays a negative correlation.
# In the nothern hemisphere, as you move away from the equator the temperature decreases.

# %%
# Linear regression on Southern Hemisphere
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Max Temp (F)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a positive correlation.")
print("In the southern hemisphere, as you get closer to the equator the temperature increases.")
plt.show()
# Out:
# Regression line equation is: y = 0.71x + 87.89
# The r-squared is: 0.8155649639596629
# The regression displays a positive correlation.
# In the southern hemisphere, as you get closer to the equator the temperature increases.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Humidity (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.") 
plt.show()
# Out:
# Regression line equation is: y = 0.37x + 51.31
# The r-squared is: 0.3129126489624308
# The regression does not display much of a correlation between the data sets.

# %%
# Southern Hemisphere
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Humidity (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.21x + 76.0
# The r-squared is: 0.15356008417697348
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Cloudiness (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.07x + 55.76
# The r-squared is: 0.03970145791988551
# The regression does not display much of a correlation between the data sets.

# %%
# Southern Hemisphere
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Cloudiness (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 1.13x + 83.64
# The r-squared is: 0.38720328478739596
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Wind Speed (mph)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.01x + 3.49
# The r-squared is: 0.06919916197776063
# The regression does not display much of a correlation between the data sets.

# %%
# Southern Hemisphere
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Wind Speed (mph)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = -0.07x + 2.08
# The r-squared is: -0.32131958915313785
# The regression does not display much of a correlation between the data sets.
